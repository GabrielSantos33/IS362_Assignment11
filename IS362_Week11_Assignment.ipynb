# %% [markdown]
# ### Assignment – Web APIs
#
# The New York Times web site provides a rich set of APIs, as described here: http://developer.nytimes.com/docs
# You’ll need to start by signing up for an API key.
# Your task is to choose one of the New York Times APIs, construct an interface in Python to read in the JSON data, and
# transform it into a pandas DataFrame.

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import requests
import json
import urllib
from pandas.io.json import json_normalize

# %% [markdown]
# ### Creating API for New York Times

# %%
api_key = 'DlWGCYWRAMI37VOfybpMDSuc07s0wYGf '
url = "https://api.nytimes.com/svc/movies/v2/reviews/search.json?"

# %% [markdown]
# ### Make the API request

# %%
request = requests.get(url, params={'api-key': api_key})
data = request.json()

# %% [markdown]
# ### JSON results

# %%
data
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2021 The New York Times Company. All Rights Reserved.',
#  'has_more': True,
#  'num_results': 20,
#  'results': [{'display_title': 'Lúa vermella',
#    'mpaa_rating': '',
#    'critics_pick': 1,
#    'byline': 'Natalia Winkelman',
#    'headline': '‘Red Moon Tide’ Review: A Village Paralyzed in Grief',
#    'summary_short': 'Subjects stand frozen against majestic landscapes in Lois Patiño’s meditation on how Galician mythology intersects with a village’s search for souls lost at sea.',
#    'publication_date': '2021-04-20',
#    'opening_date': None,
#    'date_updated': '2021-04-20 11:01:03',
#    'link': {'type': 'article',
#     'url': 'https://www.nytimes.com/2021/04/20/movies/red-moon-tide-review.html',
#     'suggested_link_text': 'Read the New York Times Review of Lúa vermella'},
#    'multimedia': {'type': 'mediumThreeByTwo210',
#     'src': 'https://static01.nyt.com/images/2021/04/19/arts/redmoon1/redmoon1-mediumThreeByTwo440.jpg',
#     'height': 140,
#     'width': 210}},
#   {'display_title': 'The Marijuana Conspiracy',
#    'mpaa_rating': '',
#    'critics_pick': 0,
#    'byline': 'Jeannette Catsoulis',
#    'headline': '‘The Marijuana Conspiracy’ Review: Grass Fed',
#    'summary_short': 'Five young women find that getting paid to get high isn’t quite as much fun as they imagined.',
#    'publication_date': '2021-04-20',
#    'opening_date': None,
#    'date_updated': '2021-04-20 11:02:03',
#    'link': {'type': 'article',
#     'url': 'https://www.nytimes.com/2021/04/20/movies/the-marijuana-conspiracy-review.html',
#     'suggested_link_text': 'Read the New York Times Review of The Marijuana Conspiracy'},
#    'multimedia': {'type': 'mediumThreeByTwo210',
#     'src': 'https://static01.nyt.com/images/2021/04/19/arts/marijuana1/marijuana1-mediumThreeByTwo440.jpg',
#     'height': 140,
#     'width': 210}},
#   {'display_title': 'Arlo the Alligator Boy',
#    'mpaa_rating': 'TV-PG',
#    'critics_pick': 0,
#    'byline': 'Amy Nicholson',
#    'headline': '‘Arlo the Alligator Boy’ Review: Of Songs and Scales',
#    'summary_short': 'This hyperactive animated Netflix musical for kids, with messages of empowerment and references to “Midnight Cowboy,” has a lot on its plate.',
#    'publication_date': '2021-04-16',
#    'opening_date': '2021-04-16',
#    'date_updated': '2021-04-16 11:01:04',
#    'link': {'type': 'article',
#     'url': 'https://www.nytimes.com/2021/04/16/movies/arlo-the-alligator-boy-review.html',
#     'suggested_link_text': 'Read the New York Times Review of Arlo the Alligator Boy'},
#    'multimedia': {'type': 'mediumThreeByTwo210',
#     'src': 'https://static01.nyt.com/images/2021/04/17/arts/arlo/arlo-mediumThreeByTwo440.jpg',
#     'height': 140,
#     'width': 210}},
#   {'display_title': 'Bill Traylor: Chasing Ghosts',
#    'mpaa_rating': '',
#    'critics_pick': 1,
#    'byline': 'Glenn Kenny',
#    'headline': '‘Bill Traylor: Chasing Ghosts’ Review: He Made a ‘Pill for the Pain’',
#    'summary_short': 'Blues, silhouettes, two-dimensional figures at play. This artist created mystical experiences from whatever scraps he could find.',
#    'publication_date': '2021-04-15',
#    'opening_date': '2021-04-16',
#    'date_updated': '2021-04-15 11:07:02',
#    'link': {'type': 'article',
#     'url': 'https://www.nytimes.com/2021/04/15/movies/bill-traylor-chasing-ghosts-review.html',
#     'suggested_link_text': 'Read the New York Times Review of Bill Traylor: Chasing Ghosts'},
#    'multimedia': {'type': 'mediumThreeByTwo210',
#     'src': 'https://static01.nyt.com/images/2021/04/15/arts/15billtraylorpix/15billtraylorpix-mediumThreeByTwo440.jpg',
#     'height': 140,
#     'width': 210}},
#   {'display_title': 'Hope',
#    'mpaa_rating': '',
#    'critics_pick': 1,
#    'byline': 'Jeannette Catsoulis',
#    'headline': '‘Hope’ Review: In Sickness and in Health',
#    'summary_short': 'In this raw Norwegian drama, a cancer diagnosis forces a longstanding couple to face the fissures in their relationship.',
#    'publication_date': '2021-04-15',
#    'opening_date': '2021-04-16',
#    'date_updated': '2021-04-15 11:08:03',
#    'link': {'type': 'article',
#     'url': 'https://www.nytimes.com/2021/04/15/movies/hope-review.html',
#     'suggested_link_text': 'Read the New York Times Review of Hope'},
#    'multimedia': {'type': 'mediumThreeByTwo210',
#     'src': 'https://static01.nyt.com/images/2021/04/14/arts/hope1/hope1-mediumThreeByTwo440.jpg',
#     'height': 140,
#     'width': 210}},
#   {'display_title': 'We Broke Up',
#    'mpaa_rating': '',
#    'critics_pick': 0,
#    'byline': 'Teo Bugbee',
#    'headline': '‘We Broke Up’ Review: Breaking Up Is Hard to Watch',
#    'summary_short': 'A longtime couple tries to keep their fractured relationship a secret during a family wedding in this melancholic romantic comedy.',
#    'publication_date': '2021-04-15',
#    'opening_date': None,
#    'date_updated': '2021-04-15 11:01:03',
#    'link': {'type': 'article',
#     'url': 'https://www.nytimes.com/2021/04/15/movies/we-broke-up-review.html',
#     'suggested_link_text': 'Read the New York Times Review of We Broke Up'},
#    'multimedia': {'type': 'mediumThreeByTwo210',
#     'src': 'https://static01.nyt.com/images/2021/04/15/arts/15webrokeup/merlin_186365127_9d588e29-ed95-4104-8aa0-b25a28ceb42f-mediumThreeByTwo440.jpg',
#     'height': 140,
#     'width': 210}},
#   {'display_title': 'Monday',
#    'mpaa_rating': 'R',
#    'critics_pick': 0,
#    'byline': 'Glenn Kenny',
#    'headline': '‘Monday’ Review: A Year of Love and Its Hangovers',
#    'summary_short': 'Fiery physical contact keeps an expat couple together in Greece, and the sex scenes are enough for a half-dozen movies.',
#    'publication_date': '2021-04-15',
#    'opening_date': '2021-04-16',
#    'date_updated': '2021-04-15 11:06:02',
#    'link': {'type': 'article',
#     'url': 'https://www.nytimes.com/2021/04/15/movies/monday-review.html',
#     'suggested_link_text': 'Read the New York Times Review of Monday'},
#    'multimedia': {'type': 'mediumThreeByTwo210',
#     'src': 'https://static01.nyt.com/images/2021/04/15/arts/15monday/15monday-mediumThreeByTwo440.jpg',
#     'height': 140,
#     'width': 210}},
#   {'display_title': '',
#    'mpaa_rating': '',
#    'critics_pick': 0,
#    'byline': 'Devika Girish',
#    'headline': '‘Downstream to Kinshasa’ Review: Sisyphean Persistence',
#    'summary_short': 'Dieudo Hamadi’s documentary follows survivors of war as they demand long-overdue government compensation.',
#    'publication_date': '2021-04-15',
#    'opening_date': None,
#    'date_updated': '0001-01-01 00:00:00',
#    'link': {'type': 'article',
#     'url': 'https://www.nytimes.com/2021/04/15/movies/downstream-to-kinshasa-review.html',
#     'suggested_link_text': 'Read the New York Times Review of '},
#    'multimedia': {'type': 'mediumThreeByTwo210',
#     'src': 'https://static01.nyt.com/images/2021/04/15/arts/15downstream-art/15downstream-art-mediumThreeByTwo440.jpg',
#     'height': 140,
#     'width': 210}},
#   {'display_title': 'Downstream to Kinshasa',
#    'mpaa_rating': '',
#    'critics_pick': 0,
#    'byline': 'Devika Girish',
#    'headline': '‘Downstream to Kinshasa’ Review: Sisyphean Persistence',
#    'summary_short': 'Dieudo Hamadi’s documentary follows survivors of war as they demand long-overdue government compensation.',
#    'publication_date': '2021-04-15',
#    'opening_date': None,
#    'date_updated': '2021-04-15 13:35:57',
#    'link': {'type': 'article',
#     'url': 'https://www.nytimes.com/2021/04/15/movies/downstream-to-kinshasa-review.html',
#     'suggested_link_text': 'Read the New York Times Review of Downstream to Kinshasa'},
#    'multimedia': {'type': 'mediumThreeByTwo210',
#     'src': 'https://static01.nyt.com/images/2021/04/15/arts/15downstream-art/15downstream-art-mediumThreeByTwo440.jpg',
#     'height': 140,
#     'width': 210}},
#   {'display_title': 'In the Earth',
#    'mpaa_rating': 'R',
#    'critics_pick': 0,
#    'byline': 'Ben Kenigsberg',
#    'headline': '‘In the Earth’ Review: Grassroots Horror',
#    'summary_short': 'Ben Wheatley gets back to basics with this horror movie conceived during the pandemic.',
#    'publication_date': '2021-04-15',
#    'opening_date': '2021-04-16',
#    'date_updated': '2021-04-15 11:02:03',
#    'link': {'type': 'article',
#     'url': 'https://www.nytimes.com/2021/04/15/movies/in-the-earth-review.html',
#     'suggested_link_text': 'Read the New York Times Review of In the Earth'},
#    'multimedia': {'type': 'mediumThreeByTwo210',
#     'src': 'https://static01.nyt.com/images/2021/04/16/arts/intheearth1/intheearth1-mediumThreeByTwo440.jpg',
#     'height': 140,
#     'width': 210}},
#   {'display_title': 'Why Did You Kill Me?',
#    'mpaa_rating': 'TV-MA',
#    'critics_pick': 0,
#    'byline': 'Calum Marsh',
#    'headline': '‘Why Did You Kill Me?’ Review: To Catfish a Killer',
#    'summary_short': 'In this Netflix true crime documentary, murder meets Myspace.',
#    'publication_date': '2021-04-15',
#    'opening_date': '2021-04-14',
#    'date_updated': '2021-04-15 11:04:03',
#    'link': {'type': 'article',
#     'url': 'https://www.nytimes.com/2021/04/15/movies/why-did-you-kill-me-review.html',
#     'suggested_link_text': 'Read the New York Times Review of Why Did You Kill Me?'},
#    'multimedia': {'type': 'mediumThreeByTwo210',
#     'src': 'https://static01.nyt.com/images/2021/04/19/arts/whydid1/whydid1-mediumThreeByTwo440.png',
#     'height': 140,
#     'width': 210}},
#   {'display_title': '',
#    'mpaa_rating': '',
#    'critics_pick': 0,
#    'byline': 'Beatrice Loayza',
#    'headline': '‘Beate’ Review: Bad Habits',
#    'summary_short': 'Factory workers and nuns team up to make lingerie in this half-baked comedy from Italy.',
#    'publication_date': '2021-04-15',
#    'opening_date': None,
#    'date_updated': '0001-01-01 00:00:00',
#    'link': {'type': 'article',
#     'url': 'https://www.nytimes.com/2021/04/15/movies/beate-review-bad-habits.html',
#     'suggested_link_text': 'Read the New York Times Review of '},
#    'multimedia': {'type': 'mediumThreeByTwo210',
#     'src': 'https://static01.nyt.com/images/2021/04/13/arts/beate1/beate1-mediumThreeByTwo440.jpg',
#     'height': 140,
#     'width': 210}},
#   {'display_title': 'Beate',
#    'mpaa_rating': '',
#    'critics_pick': 0,
#    'byline': 'Beatrice Loayza',
#    'headline': '‘Beate’ Review: Bad Habits',
#    'summary_short': 'Factory workers and nuns team up to make lingerie in this half-baked comedy from Italy.',
#    'publication_date': '2021-04-15',
#    'opening_date': None,
#    'date_updated': '2021-04-15 13:35:03',
#    'link': {'type': 'article',
#     'url': 'https://www.nytimes.com/2021/04/15/movies/beate-review-bad-habits.html',
#     'suggested_link_text': 'Read the New York Times Review of Beate'},
#    'multimedia': {'type': 'mediumThreeByTwo210',
#     'src': 'https://static01.nyt.com/images/2021/04/13/arts/beate1/beate1-mediumThreeByTwo440.jpg',
#     'height': 140,
#     'width': 210}},
#   {'display_title': 'Ride or Die',
#    'mpaa_rating': 'TV-MA',
#    'critics_pick': 0,
#    'byline': 'Natalia Winkelman',
#    'headline': '‘Ride or Die’ Review: Killing for Love',
#    'summary_short': 'After upending her life, a woman runs away with her longtime crush in this puzzling Japanese drama.',
#    'publication_date': '2021-04-15',
#    'opening_date': '2021-04-15',
#    'date_updated': '2021-04-15 11:03:03',
#    'link': {'type': 'article',
#     'url': 'https://www.nytimes.com/2021/04/15/movies/ride-or-die-review.html',
#     'suggested_link_text': 'Read the New York Times Review of Ride or Die'},
#    'multimedia': {'type': 'mediumThreeByTwo210',
#     'src': 'https://static01.nyt.com/images/2021/04/17/arts/ride1/merlin_186182577_0c925c2c-7c9d-421d-a444-2923688f4c7f-mediumThreeByTwo440.jpg',
#     'height': 140,
#     'width': 210}},
#   {'display_title': 'The Banishing',
#    'mpaa_rating': '',
#    'critics_pick': 0,
#    'byline': 'Jeannette Catsoulis',
#    'headline': '‘The Banishing’ Review: Choosing My Religion',
#    'summary_short': 'A haunted English manor serves up incoherent shocks to a young cleric and his family in this Gothic melodrama streaming on Shudder.',
#    'publication_date': '2021-04-15',
#    'opening_date': None,
#    'date_updated': '2021-04-15 11:05:02',
#    'link': {'type': 'article',
#     'url': 'https://www.nytimes.com/2021/04/15/movies/the-banishing-review.html',
#     'suggested_link_text': 'Read the New York Times Review of The Banishing'},
#    'multimedia': {'type': 'mediumThreeByTwo210',
#     'src': 'https://static01.nyt.com/images/2021/04/13/arts/banishing1/banishing1-mediumThreeByTwo440.jpg',
#     'height': 140,
#     'width': 210}},
#   {'display_title': 'Our Towns',
#    'mpaa_rating': '',
#    'critics_pick': 0,
#    'byline': 'Ben Kenigsberg',
#    'headline': '‘Our Towns’ Review: Across America, Signs of Life',
#    'summary_short': 'In this companion piece to the book of the same title, James and Deborah Fallows search for revitalization in American cities that had fallen on hard times.',
#    'publication_date': '2021-04-13',
#    'opening_date': None,
#    'date_updated': '2021-04-13 17:00:03',
#    'link': {'type': 'article',
#     'url': 'https://www.nytimes.com/2021/04/13/movies/our-towns-review.html',
#     'suggested_link_text': 'Read the New York Times Review of Our Towns'},
#    'multimedia': {'type': 'mediumThreeByTwo210',
#     'src': 'https://static01.nyt.com/images/2021/04/12/arts/ourtowns1/ourtowns1-mediumThreeByTwo440.jpg',
#     'height': 140,
#     'width': 210}},
#   {'display_title': '',
#    'mpaa_rating': '',
#    'critics_pick': 0,
#    'byline': 'Natalia Winkelman',
#    'headline': '‘Future People’ Review: Connected by Biology, Bonded by Love',
#    'summary_short': 'This documentary chronicles eight years in the lives of a group of children who form a bond after discovering they were conceived by the same sperm donor.',
#    'publication_date': '2021-04-09',
#    'opening_date': None,
#    'date_updated': '0001-01-01 00:00:00',
#    'link': {'type': 'article',
#     'url': 'https://www.nytimes.com/2021/04/09/movies/future-people-review.html',
#     'suggested_link_text': 'Read the New York Times Review of '},
#    'multimedia': {'type': 'mediumThreeByTwo210',
#     'src': 'https://static01.nyt.com/images/2021/04/10/arts/future1/future1-mediumThreeByTwo440.jpg',
#     'height': 140,
#     'width': 210}},
#   {'display_title': 'Future People',
#    'mpaa_rating': '',
#    'critics_pick': 0,
#    'byline': 'Natalia Winkelman',
#    'headline': '‘Future People’ Review: Connected by Biology, Bonded by Love',
#    'summary_short': 'This documentary chronicles eight years in the lives of a group of children who form a bond after discovering they were conceived by the same sperm donor.',
#    'publication_date': '2021-04-09',
#    'opening_date': '2021-01-01',
#    'date_updated': '2021-04-09 11:36:02',
#    'link': {'type': 'article',
#     'url': 'https://www.nytimes.com/2021/04/09/movies/future-people-review.html',
#     'suggested_link_text': 'Read the New York Times Review of Future People'},
#    'multimedia': {'type': 'mediumThreeByTwo210',
#     'src': 'https://static01.nyt.com/images/2021/04/10/arts/future1/future1-mediumThreeByTwo440.jpg',
#     'height': 140,
#     'width': 210}},
#   {'display_title': 'Thunder Force',
#    'mpaa_rating': 'PG-13',
#    'critics_pick': 0,
#    'byline': 'Jeannette Catsoulis',
#    'headline': '‘Thunder Force’ Review: Saving Chicago, One Mutant at a Time',
#    'summary_short': 'Melissa McCarthy and Octavia Spencer don superhero suits in this painfully lazy Netflix comedy.',
#    'publication_date': '2021-04-09',
#    'opening_date': '2021-04-09',
#    'date_updated': '2021-04-09 07:02:03',
#    'link': {'type': 'article',
#     'url': 'https://www.nytimes.com/2021/04/09/movies/thunder-force-review.html',
#     'suggested_link_text': 'Read the New York Times Review of Thunder Force'},
#    'multimedia': {'type': 'mediumThreeByTwo210',
#     'src': 'https://static01.nyt.com/images/2021/04/09/arts/thunder1/thunder1-mediumThreeByTwo440-v3.jpg',
#     'height': 140,
#     'width': 210}},
#   {'display_title': 'Shiva Baby',
#    'mpaa_rating': '',
#    'critics_pick': 1,
#    'byline': 'Jason Bailey',
#    'headline': '‘Shiva Baby’ Review: It’s Complicated',
#    'summary_short': 'The potential land mines of a young woman’s life are set to explode simultaneously in this tense comedy from Emma Seligman.',
#    'publication_date': '2021-04-08',
#    'opening_date': '2021-04-02',
#    'date_updated': '2021-04-08 15:29:03',
#    'link': {'type': 'article',
#     'url': 'https://www.nytimes.com/2021/04/08/movies/shiva-baby-review.html',
#     'suggested_link_text': 'Read the New York Times Review of Shiva Baby'},
#    'multimedia': {'type': 'mediumThreeByTwo210',
#     'src': 'https://static01.nyt.com/images/2021/04/10/arts/shiva1/shiva1-mediumThreeByTwo440.jpg',
#     'height': 140,
#     'width': 210}}]}

# %% [markdown]
# ### Normalize the data

# %%
df = json_normalize(data['results'])
# Out:
# <ipython-input-7-8c7ea079869e>:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   df = json_normalize(data['results'])

# %% [markdown]
# ### The dataframe

# %%
df
# Out:
#                    display_title mpaa_rating  critics_pick  \
# 0                   Lúa vermella                         1
# 1       The Marijuana Conspiracy                         0
# 2         Arlo the Alligator Boy       TV-PG             0
# 3   Bill Traylor: Chasing Ghosts                         1
# 4                           Hope                         1
# 5                    We Broke Up                         0
# 6                         Monday           R             0
# 7                                                        0
# 8         Downstream to Kinshasa                         0
# 9                   In the Earth           R             0
# 10          Why Did You Kill Me?       TV-MA             0
# 11                                                       0
# 12                         Beate                         0
# 13                   Ride or Die       TV-MA             0
# 14                 The Banishing                         0
# 15                     Our Towns                         0
# 16                                                       0
# 17                 Future People                         0
# 18                 Thunder Force       PG-13             0
# 19                    Shiva Baby                         1
#
#                  byline                                           headline  \
# 0     Natalia Winkelman  ‘Red Moon Tide’ Review: A Village Paralyzed in...
# 1   Jeannette Catsoulis       ‘The Marijuana Conspiracy’ Review: Grass Fed
# 2         Amy Nicholson  ‘Arlo the Alligator Boy’ Review: Of Songs and ...
# 3           Glenn Kenny  ‘Bill Traylor: Chasing Ghosts’ Review: He Made...
# 4   Jeannette Catsoulis           ‘Hope’ Review: In Sickness and in Health
# 5            Teo Bugbee  ‘We Broke Up’ Review: Breaking Up Is Hard to W...
# 6           Glenn Kenny  ‘Monday’ Review: A Year of Love and Its Hangovers
# 7         Devika Girish  ‘Downstream to Kinshasa’ Review: Sisyphean Per...
# 8         Devika Girish  ‘Downstream to Kinshasa’ Review: Sisyphean Per...
# 9        Ben Kenigsberg           ‘In the Earth’ Review: Grassroots Horror
# 10          Calum Marsh  ‘Why Did You Kill Me?’ Review: To Catfish a Ki...
# 11      Beatrice Loayza                         ‘Beate’ Review: Bad Habits
# 12      Beatrice Loayza                         ‘Beate’ Review: Bad Habits
# 13    Natalia Winkelman             ‘Ride or Die’ Review: Killing for Love
# 14  Jeannette Catsoulis       ‘The Banishing’ Review: Choosing My Religion
# 15       Ben Kenigsberg  ‘Our Towns’ Review: Across America, Signs of Life
# 16    Natalia Winkelman  ‘Future People’ Review: Connected by Biology, ...
# 17    Natalia Winkelman  ‘Future People’ Review: Connected by Biology, ...
